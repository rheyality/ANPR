# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in c:\users\hp\nprsys\lib\site-packages (3.2)
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
if os.name=='posix':
    # !apt-get install protobuf-complier
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. &&cp object_detection/packages/tf2/setup.py . && python -m pip install.

if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# 100% [..........................................................................] 1468733 / 1468733        1 file(s) moved.
# ^C
# Obtaining file:///C:/Users/hp/ANPR/Tensorflow/models/research/slim
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six in c:\users\hp\nprsys\lib\site-packages\six-1.16.0-py3.11.egg (from slim==0.1) (1.16.0)
# Requirement already satisfied: tf-slim>=1.1 in c:\users\hp\nprsys\lib\site-packages\tf_slim-1.1.0-py3.11.egg (from slim==0.1) (1.1.0)
# Collecting absl-py>=0.2.2 (from tf-slim>=1.1->slim==0.1)
#   Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Building wheels for collected packages: slim
#   Building editable for slim (pyproject.toml): started
#   Building editable for slim (pyproject.toml): finished with status 'done'
#   Created wheel for slim: filename=slim-0.1-0.editable-py3-none-any.whl size=2503 sha256=72a677b902b1cc00c7a3472eee2f72916dd58a142c6a6b47b6adb9fe1f7eed64
#   Stored in directory: C:\Users\hp\AppData\Local\Temp\pip-ephem-wheel-cache-ec43sqls\wheels\ff\61\5d\86102cdac9da3aa1a29a5f2618752b4a084861d0345149680e
# Successfully built slim
# Installing collected packages: absl-py, slim
# Successfully installed absl-py-2.0.0 slim-0.1

# %%
# !pip list
# Out:
# Package                       Version     Editable project location
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\apache_beam-2.51.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\contextlib2-21.6.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\cython-3.0.4-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\lvis-0.5.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\lxml-4.9.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\object_detection-0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pandas-2.1.2-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\portalocker-2.8.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pycocotools-2.0.7-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pyparsing-2.4.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\regex-2023.10.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\sacrebleu-2.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\scipy-1.11.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tabulate-0.9.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow-2.14.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow_io-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tf_models_official-2.14.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tf_slim-1.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ----------------------------- ----------- ------------------------------------------------
# absl-py                       1.4.0
# apache-beam                   2.51.0
# apache-beam                   2.51.0
# array-record                  0.4.1
# asttokens                     2.4.1
# astunparse                    1.6.3
# avro-python3                  1.10.2
# avro-python3                  1.10.2
# avro-python3                  1.10.2
# backcall                      0.2.0
# bleach                        6.1.0
# cachetools                    5.3.2
# certifi                       2023.7.22
# charset-normalizer            3.3.1
# click                         8.1.7
# cloudpickle                   2.2.1
# colorama                      0.4.6
# comm                          0.1.4
# contextlib2                   21.6.0
# contextlib2                   21.6.0
# contourpy                     1.1.1
# crcmod                        1.7
# cycler                        0.12.1
# Cython                        3.0.4
# Cython                        3.0.4
# debugpy                       1.8.0
# decorator                     5.1.1
# dill                          0.3.1.1
# dm-tree                       0.1.8
# docopt                        0.6.2
# easyocr                       1.7.1
# etils                         1.5.2
# executing                     2.0.0
# fastavro                      1.9.0
# fasteners                     0.19
# filelock                      3.13.0
# flatbuffers                   23.5.26
# fonttools                     4.43.1
# fsspec                        2023.10.0
# gast                          0.4.0
# gin-config                    0.5.0
# google-api-core               2.12.0
# google-api-python-client      2.105.0
# google-auth                   2.23.3
# google-auth-httplib2          0.1.1
# google-auth-oauthlib          1.0.0
# google-pasta                  0.2.0
# googleapis-common-protos      1.61.0
# grpcio                        1.59.0
# h5py                          3.10.0
# hdfs                          2.1.0
# httplib2                      0.18.1
# idna                          3.4
# imageio                       2.31.6
# immutabledict                 3.0.0
# importlib-resources           6.1.0
# ipykernel                     6.26.0
# ipython                       8.16.1
# jedi                          0.19.1
# Jinja2                        3.1.2
# joblib                        1.3.2
# Js2Py                         0.74
# jupyter_client                8.5.0
# jupyter_core                  5.4.0
# kaggle                        1.5.16
# keras                         2.13.1
# kiwisolver                    1.4.5
# lazy_loader                   0.3
# libclang                      16.0.6
# lvis                          0.5.3
# lvis                          0.5.3
# lxml                          4.9.3
# lxml                          4.9.3
# Markdown                      3.5
# MarkupSafe                    2.1.3
# matplotlib                    3.8.0
# matplotlib-inline             0.1.6
# ml-dtypes                     0.2.0
# mpmath                        1.3.0
# nest-asyncio                  1.5.8
# networkx                      3.2.1
# ninja                         1.11.1.1
# numpy                         1.24.0
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# object-detection              0.1
# object-detection              0.1
# objsize                       0.6.1
# opencv-python                 4.8.1.78
# opencv-python-headless        4.8.1.78
# opt-einsum                    3.3.0
# orjson                        3.9.7
# packaging                     23.2
# pandas                        2.1.2
# pandas                        2.1.2
# parso                         0.8.3
# pickleshare                   0.7.5
# Pillow                        10.0.1
# pip                           23.3.1
# platformdirs                  3.11.0
# portalocker                   2.8.2
# portalocker                   2.8.2
# promise                       2.3
# prompt-toolkit                3.0.39
# proto-plus                    1.7.1
# protobuf                      3.20.0
# psutil                        5.9.6
# pure-eval                     0.2.2
# py-cpuinfo                    9.0.0
# pyarrow                       11.0.0
# pyasn1                        0.5.0
# pyasn1-modules                0.3.0
# pyclipper                     1.3.0.post5
# pycocotools                   2.0.7
# pycocotools                   2.0.7
# pydot                         1.2.4
# Pygments                      2.16.1
# pyjsparser                    2.7.1
# pymongo                       3.11.4
# pyparsing                     2.4.7
# pyparsing                     2.4.7
# python-bidi                   0.4.2
# python-dateutil               2.8.2
# python-slugify                8.0.1
# pytz                          2022.4
# pywin32                       306
# PyYAML                        6.0.1
# pyzmq                         25.1.1
# regex                         2023.10.3
# regex                         2023.10.3
# requests                      2.31.0
# requests-oauthlib             1.3.1
# rsa                           4.9
# sacrebleu                     2.2.0
# sacrebleu                     2.2.0
# scikit-image                  0.22.0
# scikit-learn                  1.3.2
# scipy                         1.11.3
# scipy                         1.11.3
# sentencepiece                 0.1.99
# seqeval                       1.2.2
# setuptools                    65.5.0
# shapely                       2.0.2
# six                           1.16.0
# slim                          0.1         C:\Users\hp\ANPR\Tensorflow\models\research\slim
# stack-data                    0.6.3
# sympy                         1.12
# tabulate                      0.9.0
# tabulate                      0.9.0
# tensorboard                   2.13.0
# tensorboard-data-server       0.7.2
# tensorflow                    2.13.0
# tensorflow                    2.14.0
# tensorflow-datasets           4.9.3
# tensorflow-estimator          2.13.0
# tensorflow-hub                0.15.0
# tensorflow-intel              2.13.0
# tensorflow-io                 0.31.0
# tensorflow-io                 0.31.0
# tensorflow-io-gcs-filesystem  0.31.0
# tensorflow-io-gcs-filesystem  0.31.0
# tensorflow-metadata           1.14.0
# tensorflow-model-optimization 0.7.5
# termcolor                     2.3.0
# text-unidecode                1.3
# tf-models-official            2.14.2
# tf-models-official            2.14.2
# tf-slim                       1.1.0
# tf-slim                       1.1.0
# threadpoolctl                 3.2.0
# tifffile                      2023.9.26
# toml                          0.10.2
# torch                         2.1.0+cu118
# torchaudio                    2.1.0+cu118
# torchvision                   0.16.0
# tornado                       6.3.3
# tqdm                          4.66.1
# traitlets                     5.12.0
# typing_extensions             4.5.0
# tzdata                        2023.3
# tzlocal                       5.2
# uritemplate                   4.1.1
# urllib3                       2.0.7
# wcwidth                       0.2.8
# webencodings                  0.5.1
# Werkzeug                      3.0.1
# wget                          3.2
# wheel                         0.41.2
# wrapt                         1.14.1
# zipp                          3.17.0
# zstandard                     0.21.0

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.11.4: C:\Users\hp\ANPR\nprsys\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-10-31 00:22:23.487305: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE SSE2 SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W1031 00:22:23.548474 16688 batch_normalization.py:1531] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# C:\Users\hp\ANPR\nprsys\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\builders\model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W1031 00:22:24.195249 16688 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.42s
# I1031 00:22:24.898213 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.42s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 2.85s
# I1031 00:22:27.748225 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 2.85s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.73s
# I1031 00:22:28.481270 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.73s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.69s
# I1031 00:22:29.170303 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.69s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 6.57s
# I1031 00:22:35.744811 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 6.57s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1031 00:22:35.755227 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.06s
# I1031 00:22:35.817373 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.04s
# I1031 00:22:35.858653 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.04s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.04s
# I1031 00:22:35.900248 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.04s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.27s
# I1031 00:22:36.167072 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.27s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.25s
# I1031 00:22:36.419250 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.25s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.25s
# I1031 00:22:36.673740 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.25s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.24s
# I1031 00:22:36.917621 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.24s
# I1031 00:22:37.165758 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.07s
# I1031 00:22:37.236384 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I1031 00:22:37.668720 16688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1031 00:22:37.668720 16688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I1031 00:22:37.668720 16688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I1031 00:22:37.679052 16688 efficientnet_model.py:143] round_filter input=32 output=32
# I1031 00:22:37.751542 16688 efficientnet_model.py:143] round_filter input=32 output=32
# I1031 00:22:37.751542 16688 efficientnet_model.py:143] round_filter input=16 output=16
# I1031 00:22:37.983722 16688 efficientnet_model.py:143] round_filter input=16 output=16
# I1031 00:22:37.983722 16688 efficientnet_model.py:143] round_filter input=24 output=24
# I1031 00:22:38.568626 16688 efficientnet_model.py:143] round_filter input=24 output=24
# I1031 00:22:38.568626 16688 efficientnet_model.py:143] round_filter input=40 output=40
# I1031 00:22:39.418860 16688 efficientnet_model.py:143] round_filter input=40 output=40
# I1031 00:22:39.418860 16688 efficientnet_model.py:143] round_filter input=80 output=80
# I1031 00:22:40.258575 16688 efficientnet_model.py:143] round_filter input=80 output=80
# I1031 00:22:40.258575 16688 efficientnet_model.py:143] round_filter input=112 output=112
# I1031 00:22:41.116111 16688 efficientnet_model.py:143] round_filter input=112 output=112
# I1031 00:22:41.116111 16688 efficientnet_model.py:143] round_filter input=192 output=192
# I1031 00:22:42.328218 16688 efficientnet_model.py:143] round_filter input=192 output=192
# I1031 00:22:42.328218 16688 efficientnet_model.py:143] round_filter input=320 output=320
# I1031 00:22:42.640852 16688 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1031 00:22:42.811141 16688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1031 00:22:42.939718 16688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1031 00:22:42.939718 16688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 88
# I1031 00:22:42.939718 16688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 4
# I1031 00:22:42.939718 16688 efficientnet_model.py:143] round_filter input=32 output=32
# I1031 00:22:43.008491 16688 efficientnet_model.py:143] round_filter input=32 output=32
# I1031 00:22:43.008633 16688 efficientnet_model.py:143] round_filter input=16 output=16
# I1031 00:22:43.439220 16688 efficientnet_model.py:143] round_filter input=16 output=16
# I1031 00:22:43.439220 16688 efficientnet_model.py:143] round_filter input=24 output=24
# I1031 00:22:44.261686 16688 efficientnet_model.py:143] round_filter input=24 output=24
# I1031 00:22:44.261686 16688 efficientnet_model.py:143] round_filter input=40 output=40
# I1031 00:22:45.032423 16688 efficientnet_model.py:143] round_filter input=40 output=40
# I1031 00:22:45.032423 16688 efficientnet_model.py:143] round_filter input=80 output=80
# I1031 00:22:46.095145 16688 efficientnet_model.py:143] round_filter input=80 output=80
# I1031 00:22:46.095145 16688 efficientnet_model.py:143] round_filter input=112 output=112
# I1031 00:22:47.212495 16688 efficientnet_model.py:143] round_filter input=112 output=112
# I1031 00:22:47.212495 16688 efficientnet_model.py:143] round_filter input=192 output=192
# I1031 00:22:48.631606 16688 efficientnet_model.py:143] round_filter input=192 output=192
# I1031 00:22:48.631606 16688 efficientnet_model.py:143] round_filter input=320 output=320
# I1031 00:22:49.258608 16688 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1031 00:22:49.408858 16688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1031 00:22:49.561990 16688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b2
# I1031 00:22:49.572030 16688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 112
# I1031 00:22:49.572030 16688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 5
# I1031 00:22:49.575101 16688 efficientnet_model.py:143] round_filter input=32 output=32
# I1031 00:22:49.623018 16688 efficientnet_model.py:143] round_filter input=32 output=32
# I1031 00:22:49.623018 16688 efficientnet_model.py:143] round_filter input=16 output=16
# I1031 00:22:50.023398 16688 efficientnet_model.py:143] round_filter input=16 output=16
# I1031 00:22:50.023398 16688 efficientnet_model.py:143] round_filter input=24 output=24
# I1031 00:22:50.834533 16688 efficientnet_model.py:143] round_filter input=24 output=24
# I1031 00:22:50.834533 16688 efficientnet_model.py:143] round_filter input=40 output=48
# I1031 00:22:51.705928 16688 efficientnet_model.py:143] round_filter input=40 output=48
# I1031 00:22:51.705928 16688 efficientnet_model.py:143] round_filter input=80 output=88
# I1031 00:22:52.807730 16688 efficientnet_model.py:143] round_filter input=80 output=88
# I1031 00:22:52.807730 16688 efficientnet_model.py:143] round_filter input=112 output=120
# I1031 00:22:53.945270 16688 efficientnet_model.py:143] round_filter input=112 output=120
# I1031 00:22:53.945270 16688 efficientnet_model.py:143] round_filter input=192 output=208
# I1031 00:22:55.473807 16688 efficientnet_model.py:143] round_filter input=192 output=208
# I1031 00:22:55.473807 16688 efficientnet_model.py:143] round_filter input=320 output=352
# I1031 00:22:56.169818 16688 efficientnet_model.py:143] round_filter input=1280 output=1408
# I1031 00:22:56.328504 16688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1031 00:22:56.487352 16688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b3
# I1031 00:22:56.487352 16688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 160
# I1031 00:22:56.487352 16688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 6
# I1031 00:22:56.492977 16688 efficientnet_model.py:143] round_filter input=32 output=40
# I1031 00:22:56.534548 16688 efficientnet_model.py:143] round_filter input=32 output=40
# I1031 00:22:56.534548 16688 efficientnet_model.py:143] round_filter input=16 output=24
# I1031 00:22:56.995088 16688 efficientnet_model.py:143] round_filter input=16 output=24
# I1031 00:22:56.995088 16688 efficientnet_model.py:143] round_filter input=24 output=32
# I1031 00:22:57.850866 16688 efficientnet_model.py:143] round_filter input=24 output=32
# I1031 00:22:57.850866 16688 efficientnet_model.py:143] round_filter input=40 output=48
# I1031 00:22:58.748646 16688 efficientnet_model.py:143] round_filter input=40 output=48
# I1031 00:22:58.748646 16688 efficientnet_model.py:143] round_filter input=80 output=96
# I1031 00:23:00.761866 16688 efficientnet_model.py:143] round_filter input=80 output=96
# I1031 00:23:00.761866 16688 efficientnet_model.py:143] round_filter input=112 output=136
# I1031 00:23:02.368731 16688 efficientnet_model.py:143] round_filter input=112 output=136
# I1031 00:23:02.368731 16688 efficientnet_model.py:143] round_filter input=192 output=232
# I1031 00:23:04.194811 16688 efficientnet_model.py:143] round_filter input=192 output=232
# I1031 00:23:04.194811 16688 efficientnet_model.py:143] round_filter input=320 output=384
# I1031 00:23:04.866349 16688 efficientnet_model.py:143] round_filter input=1280 output=1536
# I1031 00:23:05.042404 16688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1031 00:23:05.206597 16688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b4
# I1031 00:23:05.206597 16688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 224
# I1031 00:23:05.206597 16688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I1031 00:23:05.212200 16688 efficientnet_model.py:143] round_filter input=32 output=48
# I1031 00:23:05.268092 16688 efficientnet_model.py:143] round_filter input=32 output=48
# I1031 00:23:05.268092 16688 efficientnet_model.py:143] round_filter input=16 output=24
# I1031 00:23:05.687267 16688 efficientnet_model.py:143] round_filter input=16 output=24
# I1031 00:23:05.687267 16688 efficientnet_model.py:143] round_filter input=24 output=32
# I1031 00:23:06.706454 16688 efficientnet_model.py:143] round_filter input=24 output=32
# I1031 00:23:06.706454 16688 efficientnet_model.py:143] round_filter input=40 output=56
# I1031 00:23:07.814003 16688 efficientnet_model.py:143] round_filter input=40 output=56
# I1031 00:23:07.814003 16688 efficientnet_model.py:143] round_filter input=80 output=112
# I1031 00:23:09.429465 16688 efficientnet_model.py:143] round_filter input=80 output=112
# I1031 00:23:09.429465 16688 efficientnet_model.py:143] round_filter input=112 output=160
# I1031 00:23:11.205658 16688 efficientnet_model.py:143] round_filter input=112 output=160
# I1031 00:23:11.205658 16688 efficientnet_model.py:143] round_filter input=192 output=272
# I1031 00:23:13.858735 16688 efficientnet_model.py:143] round_filter input=192 output=272
# I1031 00:23:13.858735 16688 efficientnet_model.py:143] round_filter input=320 output=448
# I1031 00:23:14.737210 16688 efficientnet_model.py:143] round_filter input=1280 output=1792
# I1031 00:23:14.881479 16688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1031 00:23:15.074721 16688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1031 00:23:15.074721 16688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 288
# I1031 00:23:15.074721 16688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I1031 00:23:15.074721 16688 efficientnet_model.py:143] round_filter input=32 output=48
# I1031 00:23:15.131324 16688 efficientnet_model.py:143] round_filter input=32 output=48
# I1031 00:23:15.131324 16688 efficientnet_model.py:143] round_filter input=16 output=24
# I1031 00:23:16.000326 16688 efficientnet_model.py:143] round_filter input=16 output=24
# I1031 00:23:16.000326 16688 efficientnet_model.py:143] round_filter input=24 output=40
# I1031 00:23:17.420605 16688 efficientnet_model.py:143] round_filter input=24 output=40
# I1031 00:23:17.420605 16688 efficientnet_model.py:143] round_filter input=40 output=64
# I1031 00:23:18.813152 16688 efficientnet_model.py:143] round_filter input=40 output=64
# I1031 00:23:18.813152 16688 efficientnet_model.py:143] round_filter input=80 output=128
# I1031 00:23:20.768368 16688 efficientnet_model.py:143] round_filter input=80 output=128
# I1031 00:23:20.768368 16688 efficientnet_model.py:143] round_filter input=112 output=176
# I1031 00:23:22.831623 16688 efficientnet_model.py:143] round_filter input=112 output=176
# I1031 00:23:22.831623 16688 efficientnet_model.py:143] round_filter input=192 output=304
# I1031 00:23:26.161833 16688 efficientnet_model.py:143] round_filter input=192 output=304
# I1031 00:23:26.161833 16688 efficientnet_model.py:143] round_filter input=320 output=512
# I1031 00:23:27.318707 16688 efficientnet_model.py:143] round_filter input=1280 output=2048
# I1031 00:23:27.492295 16688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1031 00:23:27.736097 16688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b6
# I1031 00:23:27.736097 16688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I1031 00:23:27.736097 16688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I1031 00:23:27.738206 16688 efficientnet_model.py:143] round_filter input=32 output=56
# I1031 00:23:27.789619 16688 efficientnet_model.py:143] round_filter input=32 output=56
# I1031 00:23:27.789619 16688 efficientnet_model.py:143] round_filter input=16 output=32
# I1031 00:23:28.434746 16688 efficientnet_model.py:143] round_filter input=16 output=32
# I1031 00:23:28.434746 16688 efficientnet_model.py:143] round_filter input=24 output=40
# I1031 00:23:30.007737 16688 efficientnet_model.py:143] round_filter input=24 output=40
# I1031 00:23:30.007737 16688 efficientnet_model.py:143] round_filter input=40 output=72
# I1031 00:23:31.650067 16688 efficientnet_model.py:143] round_filter input=40 output=72
# I1031 00:23:31.650067 16688 efficientnet_model.py:143] round_filter input=80 output=144
# I1031 00:23:33.948957 16688 efficientnet_model.py:143] round_filter input=80 output=144
# I1031 00:23:33.957996 16688 efficientnet_model.py:143] round_filter input=112 output=200
# I1031 00:23:36.347986 16688 efficientnet_model.py:143] round_filter input=112 output=200
# I1031 00:23:36.347986 16688 efficientnet_model.py:143] round_filter input=192 output=344
# I1031 00:23:39.966347 16688 efficientnet_model.py:143] round_filter input=192 output=344
# I1031 00:23:39.966347 16688 efficientnet_model.py:143] round_filter input=320 output=576
# I1031 00:23:41.155201 16688 efficientnet_model.py:143] round_filter input=1280 output=2304
# I1031 00:23:41.332301 16688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1031 00:23:41.580232 16688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1031 00:23:41.580232 16688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I1031 00:23:41.580232 16688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I1031 00:23:41.580232 16688 efficientnet_model.py:143] round_filter input=32 output=64
# I1031 00:23:41.643323 16688 efficientnet_model.py:143] round_filter input=32 output=64
# I1031 00:23:41.643323 16688 efficientnet_model.py:143] round_filter input=16 output=32
# I1031 00:23:42.471996 16688 efficientnet_model.py:143] round_filter input=16 output=32
# I1031 00:23:42.471996 16688 efficientnet_model.py:143] round_filter input=24 output=48
# I1031 00:23:44.272035 16688 efficientnet_model.py:143] round_filter input=24 output=48
# I1031 00:23:44.272035 16688 efficientnet_model.py:143] round_filter input=40 output=80
# I1031 00:23:46.108400 16688 efficientnet_model.py:143] round_filter input=40 output=80
# I1031 00:23:46.108400 16688 efficientnet_model.py:143] round_filter input=80 output=160
# I1031 00:23:48.970529 16688 efficientnet_model.py:143] round_filter input=80 output=160
# I1031 00:23:48.970529 16688 efficientnet_model.py:143] round_filter input=112 output=224
# I1031 00:23:52.810911 16688 efficientnet_model.py:143] round_filter input=112 output=224
# I1031 00:23:52.810911 16688 efficientnet_model.py:143] round_filter input=192 output=384
# I1031 00:23:57.325748 16688 efficientnet_model.py:143] round_filter input=192 output=384
# I1031 00:23:57.326256 16688 efficientnet_model.py:143] round_filter input=320 output=640
# I1031 00:23:59.094922 16688 efficientnet_model.py:143] round_filter input=1280 output=2560
# I1031 00:23:59.301300 16688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 82.37s
# I1031 00:23:59.603273 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 82.37s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1031 00:23:59.650955 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1031 00:23:59.650955 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.01s
# I1031 00:23:59.659097 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.01s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1031 00:23:59.659097 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1031 00:23:59.659097 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1031 00:23:59.659097 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.01s
# I1031 00:23:59.666625 16688 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.01s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 96.188s
#
# OK (skipped=1)

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                       Version   Editable project location
# ----------------------------- --------- ------------------------------------------------
# absl-py                       1.4.0
# apache-beam                   2.51.0
# apache-beam                   2.51.0
# array-record                  0.4.1
# asttokens                     2.4.1
# astunparse                    1.6.3
# avro-python3                  1.10.2
# avro-python3                  1.10.2
# avro-python3                  1.10.2
# backcall                      0.2.0
# bleach                        6.1.0
# cachetools                    5.3.2
# certifi                       2023.7.22
# charset-normalizer            3.3.1
# click                         8.1.7
# cloudpickle                   2.2.1
# colorama                      0.4.6
# comm                          0.1.4
# contextlib2                   21.6.0
# contextlib2                   21.6.0
# contourpy                     1.1.1
# crcmod                        1.7
# cycler                        0.12.1
# Cython                        3.0.4
# Cython                        3.0.4
# debugpy                       1.8.0
# decorator                     5.1.1
# dill                          0.3.1.1
# dm-tree                       0.1.8
# docopt                        0.6.2
# etils                         1.5.2
# executing                     2.0.0
# fastavro                      1.9.0
# fasteners                     0.19
# flatbuffers                   23.5.26
# fonttools                     4.43.1
# fsspec                        2023.10.0
# gast                          0.4.0
# gin-config                    0.5.0
# google-api-core               2.12.0
# google-api-python-client      2.105.0
# google-auth                   2.23.3
# google-auth-httplib2          0.1.1
# google-auth-oauthlib          1.0.0
# google-pasta                  0.2.0
# googleapis-common-protos      1.61.0
# grpcio                        1.59.0
# h5py                          3.10.0
# hdfs                          2.1.0
# httplib2                      0.18.1
# idna                          3.4
# immutabledict                 3.0.0
# importlib-resources           6.1.0
# ipykernel                     6.26.0
# ipython                       8.16.1
# jedi                          0.19.1
# joblib                        1.3.2
# Js2Py                         0.74
# jupyter_client                8.5.0
# jupyter_core                  5.4.0
# kaggle                        1.5.16
# keras                         2.13.1
# kiwisolver                    1.4.5
# libclang                      16.0.6
# lvis                          0.5.3
# lvis                          0.5.3
# lxml                          4.9.3
# lxml                          4.9.3
# Markdown                      3.5
# MarkupSafe                    2.1.3
# matplotlib                    3.8.0
# matplotlib-inline             0.1.6
# ml-dtypes                     0.2.0
# nest-asyncio                  1.5.8
# numpy                         1.24.0
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# object-detection              0.1
# object-detection              0.1
# objsize                       0.6.1
# opencv-python                 4.8.1.78
# opencv-python-headless        4.8.1.78
# opt-einsum                    3.3.0
# orjson                        3.9.7
# packaging                     23.2
# pandas                        2.1.2
# pandas                        2.1.2
# parso                         0.8.3
# pickleshare                   0.7.5
# Pillow                        10.1.0
# Pillow                        10.1.0
# pip                           23.3.1
# platformdirs                  3.11.0
# portalocker                   2.8.2
# portalocker                   2.8.2
# promise                       2.3
# prompt-toolkit                3.0.39
# proto-plus                    1.7.1
# protobuf                      3.20.0
# psutil                        5.9.6
# pure-eval                     0.2.2
# py-cpuinfo                    9.0.0
# pyarrow                       11.0.0
# pyasn1                        0.5.0
# pyasn1-modules                0.3.0
# pycocotools                   2.0.7
# pycocotools                   2.0.7
# pydot                         1.2.4
# Pygments                      2.16.1
# pyjsparser                    2.7.1
# pymongo                       3.11.4
# pyparsing                     2.4.7
# pyparsing                     2.4.7
# python-dateutil               2.8.2
# python-slugify                8.0.1
# pytz                          2022.4
# pywin32                       306
# PyYAML                        6.0.1
# pyzmq                         25.1.1
# regex                         2023.10.3
# regex                         2023.10.3
# requests                      2.31.0
# requests-oauthlib             1.3.1
# rsa                           4.9
# sacrebleu                     2.2.0
# sacrebleu                     2.2.0
# scikit-learn                  1.3.2
# scipy                         1.11.3
# scipy                         1.11.3
# sentencepiece                 0.1.99
# seqeval                       1.2.2
# setuptools                    65.5.0
# six                           1.16.0
# slim                          0.1       C:\Users\hp\ANPR\Tensorflow\models\research\slim
# stack-data                    0.6.3
# tabulate                      0.9.0
# tabulate                      0.9.0
# tensorboard                   2.13.0
# tensorboard-data-server       0.7.2
# tensorflow                    2.13.0
# tensorflow                    2.14.0
# tensorflow-datasets           4.9.3
# tensorflow-estimator          2.13.0
# tensorflow-hub                0.15.0
# tensorflow-intel              2.13.0
# tensorflow-io                 0.31.0
# tensorflow-io                 0.31.0
# tensorflow-io-gcs-filesystem  0.31.0
# tensorflow-io-gcs-filesystem  0.31.0
# tensorflow-metadata           1.14.0
# tensorflow-model-optimization 0.7.5
# termcolor                     2.3.0
# text-unidecode                1.3
# tf-models-official            2.14.2
# tf-models-official            2.14.2
# tf-slim                       1.1.0
# tf-slim                       1.1.0
# threadpoolctl                 3.2.0
# toml                          0.10.2
# tornado                       6.3.3
# tqdm                          4.66.1
# traitlets                     5.12.0
# typing_extensions             4.5.0
# tzdata                        2023.3
# tzlocal                       5.2
# uritemplate                   4.1.1
# urllib3                       2.0.7
# wcwidth                       0.2.8
# webencodings                  0.5.1
# Werkzeug                      3.0.1
# wget                          3.2
# wheel                         0.41.2
# wrapt                         1.14.1
# zipp                          3.17.0
# zstandard                     0.21.0
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\apache_beam-2.51.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\contextlib2-21.6.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\cython-3.0.4-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\lvis-0.5.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\lxml-4.9.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\object_detection-0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pandas-2.1.2-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pillow-10.1.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\portalocker-2.8.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pycocotools-2.0.7-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pyparsing-2.4.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\regex-2023.10.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\sacrebleu-2.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\scipy-1.11.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tabulate-0.9.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow-2.14.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow_io-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tf_models_official-2.14.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tf_slim-1.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# 100% [........................................................................] 20515344 / 20515344        1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'licence', 'id':1}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Traceback (most recent call last):
#   File "C:\Users\hp\ANPR\Tensorflow\scripts\generate_tfrecord.py", line 21, in <module>
#     import pandas as pd
#   File "C:\Users\hp\nprsys\Lib\site-packages\pandas-2.1.2-py3.11-win-amd64.egg\pandas\__init__.py", line 29, in <module>
#     raise ImportError(
# ImportError: Unable to import required dependencies:
# pytz: No module named 'pytz'
# dateutil: No module named 'dateutil'
# Traceback (most recent call last):
#   File "C:\Users\hp\ANPR\Tensorflow\scripts\generate_tfrecord.py", line 21, in <module>
#     import pandas as pd
#   File "C:\Users\hp\nprsys\Lib\site-packages\pandas-2.1.2-py3.11-win-amd64.egg\pandas\__init__.py", line 29, in <module>
#     raise ImportError(
# ImportError: Unable to import required dependencies:
# pytz: No module named 'pytz'
# dateutil: No module named 'dateutil'
# C:\Users\hp\nprsys\Lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\setuptools\command\easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# zip_safe flag not set; analyzing archive contents...
# object_detection.core.__pycache__.densepose_ops.cpython-311: module references __file__
# object_detection.core.__pycache__.preprocessor.cpython-311: module MAY be using inspect.stack
# object_detection.utils.__pycache__.autoaugment_utils.cpython-311: module MAY be using inspect.stack
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-0.0.2.dev0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-0.0.2.dev0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-0.0.3.dev0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-0.0.3.dev0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-0.0.3.dev1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-0.0.3.dev1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.1.0.dev1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.1.0.dev1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.1.0.dev2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.1.0.dev2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.2.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.2.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.5.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.5.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.6.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.6.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.7.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.7.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.7.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.7.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.7.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.7.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.9.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.9.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.10.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.10.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.12.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.12.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.12.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.12.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.13.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.13.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.13.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.13.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.13.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.13.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.14.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.14.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.14.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.14.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.14.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.14.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 1.0-static is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: static is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-0.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.1.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.7.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.11.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.12.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.13.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.14.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.15.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.16.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.17.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.18.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.19.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.20.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.21.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.22.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.23.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.24.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.25.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.26.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.27.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.28.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.29.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.29.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.30.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.30.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.31.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.31.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.32.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.32.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.33.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.33.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.33.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.34.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.34.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.34.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc8 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.36.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.36.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.36.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.36.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.37.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.37.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.37.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.37.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.38.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.38.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.39.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.39.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.39.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.40.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.40.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.40.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.41.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.41.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.41.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.42.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.42.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.42.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.43.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.43.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.43.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.44.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.44.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.45.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.45.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.46.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.46.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.47.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.47.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.47.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.47.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.48.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.48.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.48.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.49.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.49.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.49.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.50.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.50.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.50.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.51.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.51.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.7.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.7.7 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.8.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.8.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.9.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.9.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.10.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.10.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\setuptools\installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#   warnings.warn(
# WARNING: The wheel package is not available.
# WARNING: The wheel package is not available.
# C:\Users\hp\nprsys\Lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-02-16 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-02-23 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-03-11 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-05-21 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-06-05 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-06-26 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-08-04 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-10-04 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-10-12 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-10-21 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-10-22 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-10-23 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-10-24 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-10-25 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-10-26 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-11-29 is an invalid version and will not be supported in a future release
#   warnings.warn(
# C:\Users\hp\nprsys\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 2013-12-31 is an invalid version and will not be supported in a future release
#   warnings.warn(
# No local packages or working download links found for tensorflow-text~=2.14.0
# error: Could not find suitable distribution for Requirement.parse('tensorflow-text~=2.14.0')
#         1 file(s) copied.
# running build
# running build_py
# copying object_detection\protos\anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\argmax_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\bipartite_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_predictor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\calibration_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\center_net_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\eval_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\flexible_grid_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\fpn_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\graph_rewriter_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\grid_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\hyperparams_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\image_resizer_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\input_reader_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\keypoint_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\losses_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\mean_stddev_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\model_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\multiscale_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\optimizer_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\pipeline_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\post_processing_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\preprocessor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\region_similarity_calculator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\square_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\ssd_anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\ssd_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\string_int_label_map_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\target_assigner_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\train_pb2.py -> build\lib\object_detection\protos
# running egg_info
# writing object_detection.egg-info\PKG-INFO
# writing dependency_links to object_detection.egg-info\dependency_links.txt
# writing requirements to object_detection.egg-info\requires.txt
# writing top-level names to object_detection.egg-info\top_level.txt
# reading manifest file 'object_detection.egg-info\SOURCES.txt'
# writing manifest file 'object_detection.egg-info\SOURCES.txt'
# running install
# running bdist_egg
# running egg_info
# writing object_detection.egg-info\PKG-INFO
# writing dependency_links to object_detection.egg-info\dependency_links.txt
# writing requirements to object_detection.egg-info\requires.txt
# writing top-level names to object_detection.egg-info\top_level.txt
# reading manifest file 'object_detection.egg-info\SOURCES.txt'
# writing manifest file 'object_detection.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\build_imagenet_data.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\cifar10.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\dataset_factory.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\dataset_utils.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\download_and_convert_cifar10.py -> build\bdist.win-amd64\egg\datasets
# copying build\lib\datasets\download_and_convert_flowers.py -> build\bdist.win-amd64\egg\datasets
# ...
# Downloading https://files.pythonhosted.org/packages/f7/7e/fcf46053f73ab00ed4d9cf04433344def0d7e8d4ff3e2d5b8c480b6e1052/sacrebleu-2.2.0-py3-none-any.whl#sha256=2f9091da6639bff1b793b8dd0ec942aa30df08fa97d18697244b902e7eec6b5d
# Best match: sacrebleu 2.2.0
# Processing sacrebleu-2.2.0-py3-none-any.whl
# Installing sacrebleu-2.2.0-py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding sacrebleu 2.2.0 to easy-install.pth file
# Installing sacrebleu-script.py script to C:\Users\hp\nprsys\Scripts
# Installing sacrebleu.exe script to C:\Users\hp\nprsys\Scripts
#
# Installed c:\users\hp\nprsys\lib\site-packages\sacrebleu-2.2.0-py3.11.egg
# Searching for pyparsing==2.4.7
# Reading https://pypi.org/simple/pyparsing/
# Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl#sha256=ef9d7589ef3c200abe66653d3f1ab1033c3c419ae9b9bdb1240a85b024efc88b
# Best match: pyparsing 2.4.7
# Processing pyparsing-2.4.7-py2.py3-none-any.whl
# Installing pyparsing-2.4.7-py2.py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding pyparsing 2.4.7 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\pyparsing-2.4.7-py3.11.egg
# Searching for keras
# Reading https://pypi.org/simple/keras/
# Downloading https://files.pythonhosted.org/packages/64/29/0e2c584dc1c7d3046588c5b4272d9c6a1921c358dacf49553d8b94fd1acd/keras-2.15.0rc0-py3-none-any.whl#sha256=f1103e0be2321d15f0fd5d6d3a1a3cb391041c1d9ebe94fb623bd25f95b8ea64
# Best match: keras 2.15.0rc0
# Processing keras-2.15.0rc0-py3-none-any.whl
# Installing keras-2.15.0rc0-py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding keras 2.15.0rc0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\keras-2.15.0rc0-py3.11.egg
# Searching for tensorflow_io
# Reading https://pypi.org/simple/tensorflow_io/
# Downloading https://files.pythonhosted.org/packages/3b/e7/e59dffc32b53d2646d954b77495659363e0713cf23725781e9c7af2d13e8/tensorflow_io-0.31.0-cp311-cp311-win_amd64.whl#sha256=2c132700fa9b01651b6b2771a1baa5214d171d4f23aba226b1a621476073d2e6
# Best match: tensorflow-io 0.31.0
# Processing tensorflow_io-0.31.0-cp311-cp311-win_amd64.whl
# Installing tensorflow_io-0.31.0-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding tensorflow-io 0.31.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\tensorflow_io-0.31.0-py3.11-win-amd64.egg
# Searching for tf-models-official>=2.5.1
# Reading https://pypi.org/simple/tf-models-official/
# Downloading https://files.pythonhosted.org/packages/a8/df/c7c5c15af9b769dfbede372f8e9165e58ed113cddef2abbf5b4bf2fe9aa5/tf_models_official-2.14.2-py2.py3-none-any.whl#sha256=32050249ad1adaa99d0de40bed9e26e4d916a1d391480bcebf148804753b0433
# Best match: tf-models-official 2.14.2
# Processing tf_models_official-2.14.2-py2.py3-none-any.whl
# Installing tf_models_official-2.14.2-py2.py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding tf-models-official 2.14.2 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\tf_models_official-2.14.2-py3.11.egg
# Searching for pandas
# Reading https://pypi.org/simple/pandas/
# Downloading https://files.pythonhosted.org/packages/db/3e/db3e98911b5da217d1e3f85b6e091448cb8f8be674bdaff3c0ec0dd855e0/pandas-2.1.2-cp311-cp311-win_amd64.whl#sha256=65177d1c519b55e5b7f094c660ed357bb7d86e799686bb71653b8a4803d8ff0d
# Best match: pandas 2.1.2
# Processing pandas-2.1.2-cp311-cp311-win_amd64.whl
# Installing pandas-2.1.2-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding pandas 2.1.2 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\pandas-2.1.2-py3.11-win-amd64.egg
# Searching for scipy
# Reading https://pypi.org/simple/scipy/
# Downloading https://files.pythonhosted.org/packages/81/d7/d2537d51efb692d0c411e64267ba349e7668d40f5bc73cefe78ccd650dcd/scipy-1.11.3-cp311-cp311-win_amd64.whl#sha256=e1f97cd89c0fe1a0685f8f89d85fa305deb3067d0668151571ba50913e445820
# Best match: scipy 1.11.3
# Processing scipy-1.11.3-cp311-cp311-win_amd64.whl
# Installing scipy-1.11.3-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding scipy 1.11.3 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\scipy-1.11.3-py3.11-win-amd64.egg
# Searching for lvis
# Reading https://pypi.org/simple/lvis/
# Downloading https://files.pythonhosted.org/packages/72/b6/1992240ab48310b5360bfdd1d53163f43bb97d90dc5dc723c67d41c38e78/lvis-0.5.3-py3-none-any.whl#sha256=4f07153330df342b3161fafb46641ce7c02864113a8ddf0d6ffab6b02407bef0
# Best match: lvis 0.5.3
# Processing lvis-0.5.3-py3-none-any.whl
# Installing lvis-0.5.3-py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding lvis 0.5.3 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\lvis-0.5.3-py3.11.egg
# Searching for pycocotools
# Reading https://pypi.org/simple/pycocotools/
# Downloading https://files.pythonhosted.org/packages/24/b2/ef28a34cf6ca50b6b2f7ad81e5837ed45c252ffef22f5a704b94141ea842/pycocotools-2.0.7-cp311-cp311-win_amd64.whl#sha256=4a8ec6f439638120e11f49120e1ddb6c66e0b1f293d7884207d02703a73d25a1
# Best match: pycocotools 2.0.7
# Processing pycocotools-2.0.7-cp311-cp311-win_amd64.whl
# Installing pycocotools-2.0.7-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding pycocotools 2.0.7 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\pycocotools-2.0.7-py3.11-win-amd64.egg
# Searching for six
# Reading https://pypi.org/simple/six/
# Downloading https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl#sha256=8abb2f1d86890a2dfb989f9a77cfcfd3e47c2a354b01111771326f8aa26e0254
# Best match: six 1.16.0
# Processing six-1.16.0-py2.py3-none-any.whl
# Installing six-1.16.0-py2.py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding six 1.16.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\six-1.16.0-py3.11.egg
# Searching for tf-slim
# Reading https://pypi.org/simple/tf-slim/
# Downloading https://files.pythonhosted.org/packages/02/97/b0f4a64df018ca018cc035d44f2ef08f91e2e8aa67271f6f19633a015ff7/tf_slim-1.1.0-py2.py3-none-any.whl#sha256=fa2bab63b3925bd42601102e7f178dce997f525742596bf404fa8a6918e146ff
# Best match: tf-slim 1.1.0
# Processing tf_slim-1.1.0-py2.py3-none-any.whl
# Installing tf_slim-1.1.0-py2.py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding tf-slim 1.1.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\tf_slim-1.1.0-py3.11.egg
# Searching for contextlib2
# Reading https://pypi.org/simple/contextlib2/
# Downloading https://files.pythonhosted.org/packages/76/56/6d6872f79d14c0cb02f1646cbb4592eef935857c0951a105874b7b62a0c3/contextlib2-21.6.0-py2.py3-none-any.whl#sha256=3fbdb64466afd23abaf6c977627b75b6139a5a3e8ce38405c5b413aed7a0471f
# Best match: contextlib2 21.6.0
# Processing contextlib2-21.6.0-py2.py3-none-any.whl
# Installing contextlib2-21.6.0-py2.py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding contextlib2 21.6.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\contextlib2-21.6.0-py3.11.egg
# Searching for Cython
# Reading https://pypi.org/simple/Cython/
# Downloading https://files.pythonhosted.org/packages/fb/fe/e213d8e9cb21775bb8f9c92ff97861504129e23e33d118be1a90ca26a13e/Cython-3.0.5-py2.py3-none-any.whl#sha256=75206369504fc442c10a86ecf57b91592dca744e4592af22a47e9a774d53dd10
# Best match: Cython 3.0.5
# Processing Cython-3.0.5-py2.py3-none-any.whl
# Installing Cython-3.0.5-py2.py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding Cython 3.0.5 to easy-install.pth file
# Installing cygdb-script.py script to C:\Users\hp\nprsys\Scripts
# Installing cygdb.exe script to C:\Users\hp\nprsys\Scripts
# Installing cython-script.py script to C:\Users\hp\nprsys\Scripts
# Installing cython.exe script to C:\Users\hp\nprsys\Scripts
# Installing cythonize-script.py script to C:\Users\hp\nprsys\Scripts
# Installing cythonize.exe script to C:\Users\hp\nprsys\Scripts
#
# Installed c:\users\hp\nprsys\lib\site-packages\cython-3.0.5-py3.11.egg
# Searching for matplotlib
# Reading https://pypi.org/simple/matplotlib/
# Downloading https://files.pythonhosted.org/packages/40/d9/c1784db9db0d484c8e5deeafbaac0d6ed66e165c6eb4a74fb43a5fa947d9/matplotlib-3.8.0-cp311-cp311-win_amd64.whl#sha256=061ee58facb3580cd2d046a6d227fb77e9295599c5ec6ad069f06b5821ad1cfc
# Best match: matplotlib 3.8.0
# Processing matplotlib-3.8.0-cp311-cp311-win_amd64.whl
# Installing matplotlib-3.8.0-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding matplotlib 3.8.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\matplotlib-3.8.0-py3.11-win-amd64.egg
# Searching for lxml
# Reading https://pypi.org/simple/lxml/
# Downloading https://files.pythonhosted.org/packages/31/58/e3b3dd6bb2ab7404f1f4992e2d0e6926ed40cef8ce1b3bbefd95877499e1/lxml-4.9.3-cp311-cp311-win_amd64.whl#sha256=25f32acefac14ef7bd53e4218fe93b804ef6f6b92ffdb4322bb6d49d94cad2bc
# Best match: lxml 4.9.3
# Processing lxml-4.9.3-cp311-cp311-win_amd64.whl
# Installing lxml-4.9.3-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding lxml 4.9.3 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\lxml-4.9.3-py3.11-win-amd64.egg
# Searching for pillow
# Reading https://pypi.org/simple/pillow/
# Downloading https://files.pythonhosted.org/packages/b1/38/31def4109acd4db10672df6f806b175c0d21458f845ddc0890e43238ba7c/Pillow-10.1.0-cp311-cp311-win_amd64.whl#sha256=0f7c276c05a9767e877a0b4c5050c8bee6a6d960d7f0c11ebda6b99746068c2a
# Best match: Pillow 10.1.0
# Processing Pillow-10.1.0-cp311-cp311-win_amd64.whl
# Installing Pillow-10.1.0-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding Pillow 10.1.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\pillow-10.1.0-py3.11-win-amd64.egg
# Searching for apache-beam
# Reading https://pypi.org/simple/apache-beam/
# Downloading https://files.pythonhosted.org/packages/43/c3/c35f521f79698d749c016179acf0718c6d9c8a6ecc9d2b45f84ff92c6be2/apache_beam-2.51.0-cp311-cp311-win_amd64.whl#sha256=9facb6e2619c24d7787bf583ee3bc81df563c61d0a837ba9c8bc0369cf6db793
# Best match: apache-beam 2.51.0
# Processing apache_beam-2.51.0-cp311-cp311-win_amd64.whl
# Installing apache_beam-2.51.0-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding apache-beam 2.51.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\apache_beam-2.51.0-py3.11-win-amd64.egg
# Searching for avro-python3
# Reading https://pypi.org/simple/avro-python3/
# Downloading https://files.pythonhosted.org/packages/cc/97/7a6970380ca8db9139a3cc0b0e3e0dd3e4bc584fb3644e1d06e71e1a55f0/avro-python3-1.10.2.tar.gz#sha256=3b63f24e6b04368c3e4a6f923f484be0230d821aad65ac36108edbff29e9aaab
# Best match: avro-python3 1.10.2
# Processing avro-python3-1.10.2.tar.gz
# Writing C:\Users\hp\AppData\Local\Temp\easy_install-5_zh3c_6\avro-python3-1.10.2\setup.cfg
# Running avro-python3-1.10.2\setup.py -q bdist_egg --dist-dir C:\Users\hp\AppData\Local\Temp\easy_install-5_zh3c_6\avro-python3-1.10.2\egg-dist-tmp-37k_0zic
# Copying avro_python3-1.10.2-py3.11.egg to c:\users\hp\nprsys\lib\site-packages
# Adding avro-python3 1.10.2 to easy-install.pth file
# Installing avro script to C:\Users\hp\nprsys\Scripts
#
# Installed c:\users\hp\nprsys\lib\site-packages\avro_python3-1.10.2-py3.11.egg
# Searching for colorama
# Reading https://pypi.org/simple/colorama/
# Downloading https://files.pythonhosted.org/packages/d1/d6/3965ed04c63042e047cb6a3e6ed1a63a35087b6a609aa3a15ed8ac56c221/colorama-0.4.6-py2.py3-none-any.whl#sha256=4f1d9991f5acc0ca119f9d443620b77f9d6b33703e51011c16baf57afb285fc6
# Best match: colorama 0.4.6
# Processing colorama-0.4.6-py2.py3-none-any.whl
# Installing colorama-0.4.6-py2.py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding colorama 0.4.6 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\colorama-0.4.6-py3.11.egg
# Searching for numpy>=1.17
# Reading https://pypi.org/simple/numpy/
# Downloading https://files.pythonhosted.org/packages/82/0f/3f712cd84371636c5375d2dd70e7514d264cec6bdfc3d7997a4236e9f948/numpy-1.26.1-cp311-cp311-win_amd64.whl#sha256=3649d566e2fc067597125428db15d60eb42a4e0897fc48d28cb75dc2e0454e53
# Best match: numpy 1.26.1
# Processing numpy-1.26.1-cp311-cp311-win_amd64.whl
# Installing numpy-1.26.1-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding numpy 1.26.1 to easy-install.pth file
# Installing f2py-script.py script to C:\Users\hp\nprsys\Scripts
# Installing f2py.exe script to C:\Users\hp\nprsys\Scripts
#
# Installed c:\users\hp\nprsys\lib\site-packages\numpy-1.26.1-py3.11-win-amd64.egg
# Searching for tabulate>=0.8.9
# Reading https://pypi.org/simple/tabulate/
# Downloading https://files.pythonhosted.org/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl#sha256=024ca478df22e9340661486f85298cff5f6dcdba14f3813e8830015b9ed1948f
# Best match: tabulate 0.9.0
# Processing tabulate-0.9.0-py3-none-any.whl
# Installing tabulate-0.9.0-py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding tabulate 0.9.0 to easy-install.pth file
# Installing tabulate-script.py script to C:\Users\hp\nprsys\Scripts
# Installing tabulate.exe script to C:\Users\hp\nprsys\Scripts
#
# Installed c:\users\hp\nprsys\lib\site-packages\tabulate-0.9.0-py3.11.egg
# Searching for regex
# Reading https://pypi.org/simple/regex/
# Downloading https://files.pythonhosted.org/packages/b8/ad/3398312096118c4e62a5827664e52a04d5068e84d04142dd4a0da8a567ae/regex-2023.10.3-cp311-cp311-win_amd64.whl#sha256=b6104f9a46bd8743e4f738afef69b153c4b8b592d35ae46db07fc28ae3d5fb7c
# Best match: regex 2023.10.3
# Processing regex-2023.10.3-cp311-cp311-win_amd64.whl
# Installing regex-2023.10.3-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding regex 2023.10.3 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\regex-2023.10.3-py3.11-win-amd64.egg
# Searching for portalocker
# Reading https://pypi.org/simple/portalocker/
# Downloading https://files.pythonhosted.org/packages/17/9e/87671efcca80ba6203811540ed1f9c0462c1609d2281d7b7f53cef05da3d/portalocker-2.8.2-py3-none-any.whl#sha256=cfb86acc09b9aa7c3b43594e19be1345b9d16af3feb08bf92f23d4dce513a28e
# Best match: portalocker 2.8.2
# Processing portalocker-2.8.2-py3-none-any.whl
# Installing portalocker-2.8.2-py3-none-any.whl to c:\users\hp\nprsys\lib\site-packages
# Adding portalocker 2.8.2 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\portalocker-2.8.2-py3.11.egg
# Searching for tensorflow-io-gcs-filesystem==0.31.0
# Reading https://pypi.org/simple/tensorflow-io-gcs-filesystem/
# Downloading https://files.pythonhosted.org/packages/ac/4e/9566a313927be582ca99455a9523a097c7888fc819695bdc08415432b202/tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl#sha256=4bb37d23f21c434687b11059cb7ffd094d52a7813368915ba1b7057e3c16e414
# Best match: tensorflow-io-gcs-filesystem 0.31.0
# Processing tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl
# Installing tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding tensorflow-io-gcs-filesystem 0.31.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.11-win-amd64.egg
# Searching for tensorflow~=2.14.0
# Reading https://pypi.org/simple/tensorflow/
# Downloading https://files.pythonhosted.org/packages/80/6f/57d36f6507e432d7fc1956b2e9e8530c5c2d2bfcd8821bcbfae271cd6688/tensorflow-2.14.0-cp311-cp311-win_amd64.whl#sha256=0587ece626c4f7c4fcb2132525ea6c77ad2f2f5659a9b0f4451b1000be1b5e16
# Best match: tensorflow 2.14.0
# Processing tensorflow-2.14.0-cp311-cp311-win_amd64.whl
# Installing tensorflow-2.14.0-cp311-cp311-win_amd64.whl to c:\users\hp\nprsys\lib\site-packages
# Adding tensorflow 2.14.0 to easy-install.pth file
#
# Installed c:\users\hp\nprsys\lib\site-packages\tensorflow-2.14.0-py3.11-win-amd64.egg
# Searching for tensorflow-text~=2.14.0
# Reading https://pypi.org/simple/tensorflow-text/

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config
# Out:
# Available objects for config:
#     AliasManager
#     DisplayFormatter
#     HistoryManager
#     IPCompleter
#     IPKernelApp
#     LoggingMagics
#     MagicsManager
#     OSMagics
#     PrefilterManager
#     ScriptMagics
#     StoreMagics
#     ZMQInteractiveShell

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=5000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=5000

# %%
# !{command}
# Out:
# 2023-10-30 16:33:31.443873: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE SSE2 SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I1030 16:33:31.464950 14688 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 5000
# I1030 16:33:31.630743 14688 config_util.py:552] Maybe overwriting train_steps: 5000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1030 16:33:31.630743 14688 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From C:\Users\hp\ANPR\nprsys\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1030 16:33:31.716578 14688 deprecation.py:364] From C:\Users\hp\ANPR\nprsys\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# I1030 16:33:31.749874 14688 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# I1030 16:33:31.751991 14688 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1030 16:33:31.751991 14688 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1030 16:33:31.753003 14688 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Users\hp\ANPR\nprsys\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1030 16:33:31.786086 14688 deprecation.py:364] From C:\Users\hp\ANPR\nprsys\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Users\hp\ANPR\nprsys\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1030 16:33:31.876749 14688 deprecation.py:364] From C:\Users\hp\ANPR\nprsys\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Users\hp\ANPR\nprsys\Lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1030 16:33:48.319723 14688 deprecation.py:364] From C:\Users\hp\ANPR\nprsys\Lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\hp\ANPR\nprsys\Lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1030 16:33:56.235294 14688 deprecation.py:364] From C:\Users\hp\ANPR\nprsys\Lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From C:\Users\hp\ANPR\nprsys\Lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1030 16:34:00.617653 14688 deprecation.py:364] From C:\Users\hp\ANPR\nprsys\Lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2023-10-30 16:34:08.563469: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# C:\Users\hp\ANPR\nprsys\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I1030 16:34:30.231179 20920 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1030 16:34:52.909710 12004 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-10-30 16:35:11.202044: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# W1030 16:35:11.287697 14688 checkpoint.py:208] Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# W1030 16:35:11.287697 14688 checkpoint.py:217] Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# W1030 16:35:11.287697 14688 checkpoint.py:217] Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.momentum
# W1030 16:35:11.287697 14688 checkpoint.py:217] Value in checkpoint could not be found in the restored object: (root).optimizer.momentum

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
# !{command}
# Out:
# ^C

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
gpu=tf.config.list_physical_devices('GPU')
if gpu:
    try:
        tf.config.experimental.set_virtual_device_configuration(gpu[0],[tf.config.experimental.virtualDeviceConfiguration(memory_limit=5129)])
    except RuntimeError as e:
        print(e)

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-9')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'Cars411.png')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Applying Easyocr

# %%
detections.keys()
# Out:
# dict_keys(['detection_boxes', 'detection_scores', 'detection_classes', 'raw_detection_boxes', 'raw_detection_scores', 'detection_multiclass_scores', 'detection_anchor_indices', 'num_detections'])

# %%
import easyocr

# %%
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in c:\users\hp\anpr\nprsys\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.5 in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (0.16.0)
# Requirement already satisfied: opencv-python-headless in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (4.8.1.78)
# Requirement already satisfied: scipy in c:\users\hp\anpr\nprsys\lib\site-packages\scipy-1.11.3-py3.11-win-amd64.egg (from easyocr) (1.11.3)
# Requirement already satisfied: numpy in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (1.24.0)
# Requirement already satisfied: Pillow in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (10.0.1)
# Requirement already satisfied: scikit-image in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (0.22.0)
# Requirement already satisfied: python-bidi in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (2.0.2)
# Requirement already satisfied: pyclipper in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\hp\anpr\nprsys\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in c:\users\hp\anpr\nprsys\lib\site-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: filelock in c:\users\hp\anpr\nprsys\lib\site-packages (from torch->easyocr) (3.13.0)
# Requirement already satisfied: typing-extensions in c:\users\hp\anpr\nprsys\lib\site-packages (from torch->easyocr) (4.5.0)
# Requirement already satisfied: sympy in c:\users\hp\anpr\nprsys\lib\site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in c:\users\hp\anpr\nprsys\lib\site-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anpr\nprsys\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\hp\anpr\nprsys\lib\site-packages (from torch->easyocr) (2023.10.0)
# Requirement already satisfied: six in c:\users\hp\anpr\nprsys\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\hp\anpr\nprsys\lib\site-packages (from scikit-image->easyocr) (2.31.6)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\hp\anpr\nprsys\lib\site-packages (from scikit-image->easyocr) (2023.9.26)
# Requirement already satisfied: packaging>=21 in c:\users\hp\anpr\nprsys\lib\site-packages (from scikit-image->easyocr) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\hp\anpr\nprsys\lib\site-packages (from scikit-image->easyocr) (0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anpr\nprsys\lib\site-packages (from jinja2->torch->easyocr) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anpr\nprsys\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anpr\nprsys\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anpr\nprsys\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anpr\nprsys\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\anpr\nprsys\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\apache_beam-2.51.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\contextlib2-21.6.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\cython-3.0.4-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\lvis-0.5.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\lxml-4.9.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\object_detection-0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pandas-2.1.2-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\portalocker-2.8.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pycocotools-2.0.7-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\pyparsing-2.4.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\regex-2023.10.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\sacrebleu-2.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\scipy-1.11.3-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tabulate-0.9.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow-2.14.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow_io-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tf_models_official-2.14.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\hp\anpr\nprsys\lib\site-packages\tf_slim-1.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
detection_threshold=0.7

# %%
image=image_np_with_detections
scores=list(filter(lambda x:x>detection_threshold,detections['detection_scores']))
boxes=detections['detection_boxes'][:len(scores)]
classes=detections['detection_classes'][:len(scores)]

# %%
width= image.shape[1]
height= image.shape[0]

# %%
for idx, box in enumerate(boxes):
    print(box)
    roi = box*[height, width, height, width]
    print(roi)
    region = image[int(roi[0]):int(roi[2]),int(roi[1]):int(roi[3])]
    reader = easyocr.Reader(['en'])
    ocr_result = reader.readtext(region)
    print(ocr_result)
    plt.imshow(cv2.cvtColor(region, cv2.COLOR_BGR2RGB))
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [0.57444894 0.39424324 0.7387799  0.6167929 ]
# [153.95231676 157.69729614 197.99301386 246.7171669 ]
# [([[26, 10], [86, 10], [86, 36], [26, 36]], 'VIPER', 0.9998884705305002)]

# %%
for result in ocr_result:
    print(np.sum(np.subtract(result[0][2],result[0][1])))
    print(result[1])
# Out:
# 26
# VIPER

# %% [markdown]
# # OCR Filtering

# %%
region_threshold = 0.05

# %%
def filter_text(region, ocr_result, region_threshold):
    rectangle_size = region.shape[0]*region.shape[1]
    
    plate = [] 
    for result in ocr_result:
        length = np.sum(np.subtract(result[0][1], result[0][0]))
        height = np.sum(np.subtract(result[0][2], result[0][1]))
        
        if length*height / rectangle_size > region_threshold:
            plate.append(result[1])
    return plate

# %%
filter_text(region, ocr_result, region_threshold)
# Out:
# ['VIPER']

# %%
region_threshold = 0.6

# %%
def ocr_it(image, detections, detection_threshold, region_threshold):
    
    # Scores, boxes and classes above threhold
    scores = list(filter(lambda x: x> detection_threshold, detections['detection_scores']))
    boxes = detections['detection_boxes'][:len(scores)]
    classes = detections['detection_classes'][:len(scores)]
    
    # Full image dimensions
    width = image.shape[1]
    height = image.shape[0]
    
    # Apply ROI filtering and OCR
    for idx, box in enumerate(boxes):
        roi = box*[height, width, height, width]
        region = image[int(roi[0]):int(roi[2]),int(roi[1]):int(roi[3])]
        reader = easyocr.Reader(['en'])
        ocr_result = reader.readtext(region)
        
        text = filter_text(region, ocr_result, region_threshold)
        
        plt.imshow(cv2.cvtColor(region, cv2.COLOR_BGR2RGB))
        plt.show()
        print(text)
        return text, region

# %%
text, region = ocr_it(image_np_with_detections, detections, detection_threshold, region_threshold)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# []

# %% [markdown]
# # Save Results

# %%
import csv
import uuid

# %%
'{}.jpg'.format(uuid.uuid1())
# Out:
# '0ee74a12-77b2-11ee-bced-f889d2b26644.jpg'

# %%
def save_results(text, region, csv_filename, folder_path):
    img_name = '{}.jpg'.format(uuid.uuid1())
    
    cv2.imwrite(os.path.join(folder_path, img_name), region)
    
    with open(csv_filename, mode='a', newline='') as f:
        csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        csv_writer.writerow([img_name, text])

# %%
save_results(text, region, 'detection_results.csv', 'Detection_Images')

# %% [markdown]
# # 10. Real-Time Detections

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)
    try:
        text, region = ocr_it(image_np_with_detections, detections, detection_threshold, region_threshold)
        save_results(text, region, 'detection_results.csv', 'Detection_Images')
    except:
        pass

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['SAv335C0']
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['SA0335C0']
# ['SAv335C0']
